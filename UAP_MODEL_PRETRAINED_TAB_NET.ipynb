# %% [markdown]
# <a href="https://colab.research.google.com/github/AgilAptanaDwiPutra/UAP_PRAKTIKUM/blob/main/UAP_MODEL_PRETRAINED_TAB_NET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytorch-tabnet
# Out:
# Requirement already satisfied: pytorch-tabnet in /usr/local/lib/python3.12/dist-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (2.0.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (1.16.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (2.9.0+cpu)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.12/dist-packages (from pytorch-tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->pytorch-tabnet) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.3->pytorch-tabnet) (3.0.3)

# %% [markdown]
# Import Library dan load dataset

# %%
import os
import numpy as np
import pandas as pd
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from pytorch_tabnet.tab_model import TabNetRegressor

# %%
df = pd.read_csv("dataset_lagu.csv")

TARGET_COL = "popularity"
print(df.shape)
# Out:
# (114000, 21)

# %% [markdown]
# Preprocessing

# %%
DROP_COLS = [
    "track_id",
    "track_name",
    "album_id",
    "album_name",
    "artist_id",
    "artist_name"
]

for c in DROP_COLS:
    if c in df.columns:
        df.drop(columns=c, inplace=True)

# %%
# pastikan track_genre ada
assert "track_genre" in df.columns, "track_genre tidak ditemukan"

df = pd.get_dummies(df, columns=["track_genre"], prefix="genre")

# %% [markdown]
# Penyesuaian dimensi untuk tabnet

# %%
df = df.select_dtypes(include=["int64", "float64"])
assert df.select_dtypes(include=["object"]).empty

# %%
X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL].values.reshape(-1, 1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Splitting data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# Model TABNET

# %%
model = TabNetRegressor(
    n_d=32,
    n_a=32,
    n_steps=5,
    gamma=1.5,
    lambda_sparse=1e-4,
    seed=42,
    verbose=1
)

model.fit(
    X_train=X_train,
    y_train=y_train,
    eval_set=[(X_test, y_test)],
    max_epochs=50,
    patience=8,
    batch_size=4096,
    virtual_batch_size=512,
    num_workers=0,
    drop_last=False
)
# Out:
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 884.05121| val_0_mse: 505.0528|  0:00:06s
# epoch 1  | loss: 491.71296| val_0_mse: 482.94308|  0:00:14s
# epoch 2  | loss: 482.42515| val_0_mse: 476.23218|  0:00:21s
# epoch 3  | loss: 479.53263| val_0_mse: 473.02069|  0:00:29s
# epoch 4  | loss: 475.24198| val_0_mse: 471.13593|  0:00:36s
# epoch 5  | loss: 476.30922| val_0_mse: 469.59561|  0:00:43s
# epoch 6  | loss: 473.39733| val_0_mse: 467.78754|  0:00:51s
# epoch 7  | loss: 468.59319| val_0_mse: 461.91855|  0:00:57s
# epoch 8  | loss: 466.76683| val_0_mse: 459.97803|  0:01:06s
# epoch 9  | loss: 464.04009| val_0_mse: 459.15201|  0:01:14s
# epoch 10 | loss: 461.24632| val_0_mse: 457.53683|  0:01:21s
# epoch 11 | loss: 463.09563| val_0_mse: 459.00894|  0:01:28s
# epoch 12 | loss: 460.30597| val_0_mse: 451.88596|  0:01:35s
# epoch 13 | loss: 459.49634| val_0_mse: 453.7113|  0:01:43s
# epoch 14 | loss: 456.90525| val_0_mse: 450.47601|  0:01:50s
# epoch 15 | loss: 456.67085| val_0_mse: 451.05045|  0:01:57s
# epoch 16 | loss: 457.47743| val_0_mse: 452.92294|  0:02:04s
# epoch 17 | loss: 454.72307| val_0_mse: 449.94913|  0:02:11s
# epoch 18 | loss: 455.75134| val_0_mse: 450.18683|  0:02:19s
# epoch 19 | loss: 455.60071| val_0_mse: 449.78558|  0:02:26s
# epoch 20 | loss: 455.05407| val_0_mse: 449.83316|  0:02:33s
# epoch 21 | loss: 454.96606| val_0_mse: 453.85251|  0:02:40s
# epoch 22 | loss: 454.34606| val_0_mse: 453.74078|  0:02:47s
# epoch 23 | loss: 453.4284| val_0_mse: 449.04446|  0:02:55s
# epoch 24 | loss: 452.06673| val_0_mse: 445.73767|  0:03:01s
# epoch 25 | loss: 448.52103| val_0_mse: 445.09924|  0:03:09s
# epoch 26 | loss: 450.97392| val_0_mse: 448.34503|  0:03:16s
# epoch 27 | loss: 451.83892| val_0_mse: 448.88452|  0:03:23s
# epoch 28 | loss: 451.43225| val_0_mse: 446.61243|  0:03:31s
# epoch 29 | loss: 450.60929| val_0_mse: 450.10446|  0:03:38s
# epoch 30 | loss: 451.86968| val_0_mse: 443.95956|  0:03:45s
# epoch 31 | loss: 448.10189| val_0_mse: 446.59149|  0:03:52s
# epoch 32 | loss: 446.4773| val_0_mse: 445.62268|  0:03:59s
# epoch 33 | loss: 446.01101| val_0_mse: 443.1304|  0:04:07s
# epoch 34 | loss: 445.75928| val_0_mse: 445.94482|  0:04:14s
# epoch 35 | loss: 445.67933| val_0_mse: 441.13773|  0:04:21s
# epoch 36 | loss: 444.13483| val_0_mse: 444.14746|  0:04:28s
# epoch 37 | loss: 443.92354| val_0_mse: 441.4664|  0:04:35s
# epoch 38 | loss: 444.17291| val_0_mse: 440.63141|  0:04:42s
# epoch 39 | loss: 443.38539| val_0_mse: 440.36746|  0:04:50s
# epoch 40 | loss: 442.81207| val_0_mse: 436.85562|  0:04:57s
# epoch 41 | loss: 442.66491| val_0_mse: 437.04346|  0:05:04s
# epoch 42 | loss: 441.51177| val_0_mse: 440.43637|  0:05:11s
# epoch 43 | loss: 441.84017| val_0_mse: 441.18781|  0:05:18s
# epoch 44 | loss: 445.5226| val_0_mse: 438.116 |  0:05:26s
# epoch 45 | loss: 444.21691| val_0_mse: 440.50003|  0:05:33s
# epoch 46 | loss: 442.9249| val_0_mse: 438.29324|  0:05:40s
# epoch 47 | loss: 440.52316| val_0_mse: 440.82745|  0:05:47s
# epoch 48 | loss: 440.36094| val_0_mse: 434.9436|  0:05:54s
# epoch 49 | loss: 441.70225| val_0_mse: 436.41159|  0:06:02s
# Stop training because you reached max_epochs = 50 with best_epoch = 48 and best_val_0_mse = 434.9436
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# Evaluasi

# %%
y_pred = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("📊 Regression Metrics:")
print({
    "RMSE": rmse,
    "MAE": mae,
    "R2": r2
})
# Out:
# 📊 Regression Metrics:
# {'RMSE': np.float64(20.85530156856105), 'MAE': 16.802974700927734, 'R2': 0.11862123012542725}

# %% [markdown]
# Save Model

# %%
SAVE_DIR = "saved_model"
os.makedirs(SAVE_DIR, exist_ok=True)

model.save_model(os.path.join(SAVE_DIR, "tabnet_model"))

joblib.dump(
    {
        "feature_cols": X.columns.tolist(),
        "scaler": scaler
    },
    os.path.join(SAVE_DIR, "preprocessing.pkl")
)

print(os.listdir(SAVE_DIR))
# Out:
# Successfully saved model at saved_model/tabnet_model.zip
# ['preprocessing.pkl', 'tabnet_model.zip']

# %%
rm -rf saved_model
